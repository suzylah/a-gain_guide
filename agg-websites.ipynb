# %% [markdown]
# <a href="https://colab.research.google.com/github/suzylah/a-gain_guide/blob/main/agg-websites.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request,sys,time
from bs4 import BeautifulSoup
import requests
import pandas as pd
import json

# !pip install feedparser
import feedparser
# !pip install lxml
import lxml

# Sources
sourceurl = 'https://a-gain.guide/map'
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 1.3 MB/s eta 0:00:00
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6047 sha256=3d4a15ce144e8bd78403454309f5932ba7c97b54e5504afa98bc715bfa901dcc
#   Stored in directory: /root/.cache/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built sgmllib3k
# ...

# %%
def scrape_page( url ):
  page = requests.get(url)
  art = BeautifulSoup(page.text, "html.parser")
  print(page)
  print(art)
  #div = art.find(class_ = "links")

  try:
    print(div)
    #category = cat.a.text
    #if "Textiles" in category :
     # print(category)
    #else:
    #  print("no")
  except:
    print(url)

scrape_page(sourceurl)
# Out:
# <Response [200]>
# <!DOCTYPE html>
#
# <html lang="de">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1.0, maximum-scale=1" name="viewport"/>
# <title>A–Gain Guide | Map</title>
# <meta content="Die digitale Plattform für eine nachhaltige Nutzung von Mode zeigt Dir neue Wege für Deine gebrauchte Kleidung in Berlin." itemprop="description" name="description"/>
# <meta content="https://a-gain.guide/assets/images/a-gain-guide__social.jpg" itemprop="image" name="image"/>
# <meta content="A–Gain Guide | Map" property="og:title">
# <meta content="https://a-gain.guide/assets/images/a-gain-guide__social.jpg" property="og:image">
# <meta content="Die digitale Plattform für eine nachhaltige Nutzung von Mode zeigt Dir neue Wege für Deine gebrauchte Kleidung in Berlin." property="og:description">
# <meta content="https://a-gain.guide/de/map" property="og:url">
# <meta content="A–Gain Guide | Map" property="og:site_name"/>
# ...

# %%
from urllib import request
import requests  # Import the requests library
from bs4 import BeautifulSoup
import json
url = 'https://a-gain.guide/media/pages/map/2f46f830bf-1736777747/stakeholders-1736777692906.json'
html = request.urlopen(url).read()
soup = BeautifulSoup(html,'html.parser')
site_json=json.loads(soup.text)


for a in site_json['features']:
  #print(a['properties'])
  if a['properties'].get('website'):
    url = a['properties']['website']
    try:
      if url.startswith(("http", "https")):
        response = requests.get(url)  # Make a GET request to the URL
      else:
        response = requests.get('https://' + url)
      if not response.ok:
        print(url)
        print(f"Request returned {response.status_code} : '{response.reason}'")
    except:
      print("Unsuccessful at: " + url)
# Out:
# Unsuccessful at: www.lunettes-selection.de
# Unsuccessful at: https://amitola-berlin.de
# Unsuccessful at: https://sekund√§r-schick.de
# https://www.versa-aesthetics.com
# Request returned 404 : 'Not Found'
# https://yesilcember.eu/de/startseite/
# Request returned 404 : 'Not Found'
# Unsuccessful at: https://jenah-st.com/
# Unsuccessful at: https://schneideratelier-laouva.de
# https://stz-prenzlauerberg.de/unser-haus/neue-kleidertauschstation-im-hof/
# Request returned 404 : 'Not Found'
# Unsuccessful at: Annahme von Kleidung, Annahme von Schuhen, Annahme von Reststoffen, Annahme von sonstigen Textilien, Verkauf von Reststoffen, Textilsortierung, Textilrecycling
# https://www.die-schicke-ria.de
# Request returned 403 : 'Forbidden'
# https://www.zanoni-berlin.de
# Request returned 403 : 'Forbidden'
# http://garments-vintage.de
# Request returned 404 : 'Not Found'
# https://berlin-steil.de
# Request returned 403 : 'Forbidden'
# http://mankii-vintage.com
# ...
